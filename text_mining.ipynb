# %% [markdown]
# ## Import Libraries

# %%
// TODO: 
    - Find API for data collection
    - Data Cleaning
    - Feature generation
    - Feature Engineering/selection
    - Model Train
    - Model Test
    - Model Evaluation
